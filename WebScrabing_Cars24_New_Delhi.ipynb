# %%
import pandas as pd

# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as ec
import json
import time
from selenium.webdriver.chrome.service import Service
url = "https://www.cars24.com/buy-used-cars-new-delhi/"

driver = webdriver.Chrome()


driver.get(url)
item = []
last_height = driver.execute_script("return document.body.scrollHeight")
itemTargetcount = 30

while itemTargetcount > len(item):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

    time.sleep(6)

    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height 
    
    
    elements = driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > h3')
    car_name = []
    for element in elements:
        car_name.append(element.text)
    

#     elements2 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     per_km = []
#     for element in elements2:
#         per_km.append(element.text)
    
#     elements3 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     car_type_pertor = []
#     for element in elements3:
#         car_type_pertor.append(element.text)
        
#     elements4 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     amount = []
#     for element in elements4:
#         amount.append(element.text)
        
#     elements5 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     manual = []
#     for element in elements5:
#         manual.append(element.text)
        
#     elements6 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div.-EPGU > span')
#     emi = []
#     for element in elements5:
#         emi.append(element.text)
    
    
    
    
                                        

                                        
print(car_name)
print(len(car_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 60
#      36         car_name.append(element.text)
#      38 #     elements4 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#      39 #     amount = []
#      40 #     for element in elements4:
#    (...)
#      50 #     for element in elements5:
#      51 #         emi.append(element.text)
# ---> 60 print(car_name)
#      61 print(len(car_name))
#
# NameError: name 'car_name' is not defined

# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as ec
import json
import time
from selenium.webdriver.chrome.service import Service
url = "https://www.cars24.com/buy-used-cars-delhi-ncr/"

driver = webdriver.Chrome()


driver.get(url)
item = []
last_height = driver.execute_script("return document.body.scrollHeight")
itemTargetcount = 30

while itemTargetcount > len(item):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

    time.sleep(6)

    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height 
    
    
#     elements = driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > h3')
#     car_name = []
#     for element in elements:
#         car_name.append(element.text)
    

#     elements2 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     per_km = []
#     for element in elements2:
#         per_km.append(element.text)
    
    elements3 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > ul > li')
    car_type_pertor = []
    for element in elements3:
        car_type_pertor.append(element.text)
        
#     elements4 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     amount = []
#     for element in elements4:
#         amount.append(element.text)
        
#     elements5 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     manual = []
#     for element in elements5:
#         manual.append(element.text)
        
#     elements6 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div.-EPGU > span')
#     emi = []
#     for element in elements5:
#         emi.append(element.text)
    
    
    
    
                                        

                                        
print(car_type_pertor)
print(len(car_type_pertor))
# body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div:nth-child(4) > div > div > a:nth-child(1) > div > div._2YB7p > ul > li:nth-child(3)

# %%
distance_covered = []
for i in range(0,len(car_type_pertor),5):
    distance_covered.append(car_type_pertor[i])
print(distance_covered)
print(len(distance_covered))

# %%
fuel_type = []
for i in range(2,len(car_type_pertor),5):
    fuel_type.append(car_type_pertor[i])
print(fuel_type)
print(len(fuel_type))
# Out:
# ['PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'PETROL', 'PETROL', 'DIESEL', 'PETROL', 'PETROL', 'CNG', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'DIESEL', 'PETROL', 'CNG', 'DIESEL', 'PETROL', 'DIESEL', 'PETROL', 'DIESEL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'PETROL', 'CNG', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'DIESEL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL', 'DIESEL', 'CNG', 'PETROL', 'PETROL', 'CNG', 'PETROL', 'DIESEL', 'PETROL', 'PETROL', 'DIESEL', 'P
# ...

# %%
operate = []
for i in range(4,len(car_type_pertor),5):
    operate.append(car_type_pertor[i])
print(operate)
print(len(operate))
# Out:
# ['MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'AUTOMATIC', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'MANUAL',
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as ec
import json
import time
from selenium.webdriver.chrome.service import Service
url = "https://www.cars24.com/buy-used-cars-delhi-ncr/"

driver = webdriver.Chrome()


driver.get(url)
item = []
last_height = driver.execute_script("return document.body.scrollHeight")
itemTargetcount = 30

while itemTargetcount > len(item):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

    time.sleep(6)

    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height 
    
    
#     elements = driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > h3')
#     car_name = []
#     for element in elements:
#         car_name.append(element.text)
    

#     elements2 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     per_km = []
#     for element in elements2:
#         per_km.append(element.text)
    
#     elements3 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     car_type_pertor = []
#     for element in elements3:
#         car_type_pertor.append(element.text)
        
    elements4 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > div._2KyOK > strong')
    amountt = []
    for element in elements4:
        amountt.append(element.text)
        
#     elements5 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     manual = []
#     for element in elements5:
#         manual.append(element.text)
        
#     elements6 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div.-EPGU > span')
#     emi = []
#     for element in elements6:
#         emi.append(element.text)
    
    
    
    
                                        

                                        
print(amountt)
print(len(amountt))
# Out:
# ['₹2.41 Lakh', '₹7.95 Lakh', '₹4.46 Lakh', '₹4.06 Lakh', '₹16.89 Lakh', '₹3.40 Lakh', '₹5.71 Lakh', '₹8.73 Lakh', '₹5.72 Lakh', '₹6.63 Lakh', '₹8.98 Lakh', '₹8.71 Lakh', '₹3.84 Lakh', '₹7.32 Lakh', '₹6.10 Lakh', '₹6.44 Lakh', '₹4.35 Lakh', '₹6.49 Lakh', '₹3.74 Lakh', '₹5.57 Lakh', '₹6.29 Lakh', '₹1.83 Lakh', '₹6.33 Lakh', '₹4.59 Lakh', '₹9.19 Lakh', '₹9.99 Lakh', '₹5.51 Lakh', '₹4.36 Lakh', '₹4.42 Lakh', '₹10.90 Lakh', '₹9.18 Lakh', '₹3.98 Lakh', '₹6.02 Lakh', '₹9.66 Lakh', '₹5.03 Lakh', '₹5.45 Lakh', '₹6.26 Lakh', '₹6.58 Lakh', '₹4.76 Lakh', '₹2.69 Lakh', '₹3.76 Lakh', '₹2.32 Lakh', '₹10.42 Lakh', '₹5.18 Lakh', '₹5.41 Lakh', '₹11.03 Lakh', '₹6.35 Lakh', '₹8.81 Lakh', '₹2.13 Lakh', '₹6.70 Lakh', '₹3.86 Lakh', '₹5.70 Lakh', '₹8.68 Lakh', '₹7.80 Lakh', '₹4.69 Lakh', '₹4.52 Lakh', '₹10.57 Lakh', '₹4.87 Lakh', '₹9.86 Lakh', '₹11.51 Lakh', '₹8.78 Lakh', '₹8.53 Lakh', '₹7.42 Lakh', '₹22.15 Lakh', '₹9.79 Lakh', '₹4.31 Lakh', '₹6.10 Lakh', '₹10.95 Lakh', '₹4.33 Lakh', '₹9.94 Lakh', '₹9.30 La
# ...

# %%
amount = []
for i in amountt:
    rrr = (i.split())
    rr = rrr[0]
    rr = rr[1::]
    amount.append(float(rr))
print(amount)
print(len(amount))
# Out:
# [2.41, 7.95, 4.46, 4.06, 16.89, 3.4, 5.71, 8.73, 5.72, 6.63, 8.98, 8.71, 3.84, 7.32, 6.1, 6.44, 4.35, 6.49, 3.74, 5.57, 6.29, 1.83, 6.33, 4.59, 9.19, 9.99, 5.51, 4.36, 4.42, 10.9, 9.18, 3.98, 6.02, 9.66, 5.03, 5.45, 6.26, 6.58, 4.76, 2.69, 3.76, 2.32, 10.42, 5.18, 5.41, 11.03, 6.35, 8.81, 2.13, 6.7, 3.86, 5.7, 8.68, 7.8, 4.69, 4.52, 10.57, 4.87, 9.86, 11.51, 8.78, 8.53, 7.42, 22.15, 9.79, 4.31, 6.1, 10.95, 4.33, 9.94, 9.3, 15.95, 8.52, 1.84, 5.42, 6.46, 7.87, 3.03, 3.38, 5.16, 12.05, 12.51, 8.36, 6.38, 9.97, 7.53, 2.31, 5.3, 7.59, 4.8, 5.75, 13.82, 3.72, 8.23, 3.67, 6.13, 8.37, 11.49, 12.34, 12.5, 16.29, 5.01, 14.78, 3.7, 5.16, 7.85, 6.14, 5.11, 5.54, 2.77, 11.18, 7.66, 12.86, 10.0, 4.13, 6.99, 2.26, 8.77, 7.44, 3.27, 9.19, 7.66, 4.77, 9.6, 2.73, 7.74, 6.38, 6.85, 12.59, 6.96, 3.27, 3.49, 5.77, 4.18, 2.09, 9.0, 4.33, 7.74, 6.28, 7.15, 9.95, 4.27, 7.78, 5.33, 4.0, 11.85, 4.97, 5.34, 5.49, 6.22, 3.97, 6.01, 3.68, 12.49, 6.2, 8.43, 19.16, 4.04, 11.14, 5.72, 6.73, 6.31, 2.68, 4.41, 5.02,
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup 
from selenium.webdriver.common.by import By 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as ec
import json
import time
from selenium.webdriver.chrome.service import Service
url = "https://www.cars24.com/buy-used-cars-delhi-ncr/"

driver = webdriver.Chrome()


driver.get(url)
item = []
last_height = driver.execute_script("return document.body.scrollHeight")
itemTargetcount = 30

while itemTargetcount > len(item):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

    time.sleep(6)

    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height 
    
    
#     elements = driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div> div > div > a > div > div._2YB7p > h3')
#     car_name = []
#     for element in elements:
#         car_name.append(element.text)
    

#     elements2 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     per_km = []
#     for element in elements2:
#         per_km.append(element.text)
    
#     elements3 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     car_type_pertor = []
#     for element in elements3:
#         car_type_pertor.append(element.text)
        
#     elements4 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div._2KyOK > strong')
#     amount = []
#     for element in elements4:
#         amount.append(element.text)
        
#     elements5 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > ul > li')
#     manual = []
#     for element in elements5:
#         manual.append(element.text)
        
    elements6 =driver.find_elements(By.CSS_SELECTOR,'body > div.js-content > div._3fBVe > div.LhTM6 > div > div > div._2d2CZ > div > div > div > a > div > div._2YB7p > div.-EPGU > span')
    emi = []
    for element in elements6:
        emi.append(element.text)
    
    
    
    
                                        

                                        
print(emi)
print(len(emi))
# Out:
# ['EMIs from ₹4,712/month', 'EMIs from ₹15,542/month', 'EMIs from ₹8,719/month', 'EMIs from ₹7,937/month', 'EMIs from ₹32,149/month', 'EMIs from ₹7,560/month', 'EMIs from ₹11,163/month', 'EMIs from ₹16,617/month', 'EMIs from ₹11,183/month', 'EMIs from ₹12,962/month', 'EMIs from ₹17,093/month', 'EMIs from ₹16,579/month', 'EMIs from ₹7,507/month', 'EMIs from ₹16,283/month', 'EMIs from ₹11,926/month', 'EMIs from ₹12,590/month', 'EMIs from ₹8,504/month', 'EMIs from ₹12,692/month', 'EMIs from ₹7,312/month', 'EMIs from ₹10,889/month', 'EMIs from ₹12,297/month', 'EMIs from ₹8,614/month', 'EMIs from ₹14,081/month', 'EMIs from ₹8,974/month', 'EMIs from ₹17,492/month', 'EMIs from ₹19,015/month', 'EMIs from ₹10,772/month', 'EMIs from ₹8,524/month', 'EMIs from ₹8,641/month', 'EMIs from ₹20,747/month', 'EMIs from ₹17,473/month', 'EMIs from ₹7,781/month', 'EMIs from ₹11,769/month', 'EMIs from ₹18,383/month', 'EMIs from ₹9,834/month', 'EMIs from ₹10,655/month', 'EMIs from ₹12,238/month', 'EMIs from 
# ...

# %%
emi_amount = []
for i in range(len(emi)):
    a = emi[i].split()
    k = a[2].index("/")
    emi_amount.append(a[2][1:k])
print(emi_amount)
# Out:
# ['4,712', '15,542', '8,719', '7,937', '32,149', '7,560', '11,163', '16,617', '11,183', '12,962', '17,093', '16,579', '7,507', '16,283', '11,926', '12,590', '8,504', '12,692', '7,312', '10,889', '12,297', '8,614', '14,081', '8,974', '17,492', '19,015', '10,772', '8,524', '8,641', '20,747', '17,473', '7,781', '11,769', '18,383', '9,834', '10,655', '12,238', '12,864', '9,306', '5,259', '7,351', '4,536', '19,834', '10,127', '10,577', '20,995', '12,414', '16,769', '4,164', '13,093', '7,546', '11,144', '16,522', '15,249', '9,169', '8,837', '20,119', '9,521', '18,768', '21,908', '16,708', '16,228', '14,506', '72,516', '21,286', '8,426', '11,926', '23,808', '8,465', '21,612', '17,702', '30,359', '16,217', '6,111', '10,596', '12,629', '15,386', '5,924', '6,598', '10,080', '22,936', '23,812', '15,912', '14,192', '18,977', '14,721', '6,083', '10,362', '16,884', '9,384', '11,241', '26,299', '8,275', '15,665', '7,175', '11,984', '15,932', '21,870', '23,488', '23,789', '31,007', '9,795', '28,132',
# ...

# %%
print(len(emi))
# Out:
# 850

# %%
year = []
for i in range(0,len(car_name)):
    a = car_name[i]
    b = a.split()
    year.append(int(b[0]))
print(year)
print(len(year))
# Out:
# [2016, 2019, 2015, 2019, 2022, 2015, 2022, 2021, 2018, 2018, 2020, 2020, 2022, 2019, 2016, 2019, 2017, 2019, 2018, 2019, 2021, 2011, 2017, 2017, 2017, 2024, 2020, 2017, 2017, 2022, 2022, 2015, 2017, 2023, 2016, 2015, 2020, 2020, 2018, 2018, 2017, 2015, 2021, 2021, 2018, 2021, 2021, 2020, 2015, 2022, 2018, 2022, 2021, 2022, 2023, 2020, 2022, 2017, 2019, 2022, 2019, 2019, 2018, 2017, 2019, 2018, 2022, 2019, 2018, 2019, 2021, 2021, 2022, 2012, 2021, 2016, 2020, 2017, 2018, 2018, 2023, 2021, 2022, 2019, 2020, 2016, 2013, 2017, 2017, 2017, 2022, 2021, 2016, 2022, 2015, 2022, 2021, 2021, 2020, 2018, 2020, 2021, 2019, 2021, 2019, 2022, 2018, 2016, 2014, 2014, 2021, 2021, 2019, 2023, 2018, 2016, 2016, 2022, 2019, 2021, 2022, 2019, 2015, 2021, 2013, 2019, 2023, 2017, 2021, 2020, 2017, 2017, 2021, 2018, 2011, 2023, 2017, 2021, 2019, 2023, 2022, 2015, 2022, 2021, 2019, 2019, 2019, 2017, 2019, 2017, 2013, 2023, 2015, 2019, 2019, 2022, 2020, 2017, 2019, 2020, 2022, 2020, 2011, 2019, 2022, 2022, 2
# ...

# %%
brand = []
for i in range(0,len(car_name)):
    a = car_name[i]
    b = a.split()
    brand.append(b[1])
print(brand)
print(len(brand))
# Out:
# ['Maruti', 'Hyundai', 'Hyundai', 'Maruti', 'Hyundai', 'Maruti', 'Nissan', 'Maruti', 'Honda', 'Maruti', 'Mahindra', 'Hyundai', 'Maruti', 'Ford', 'Ford', 'Toyota', 'Maruti', 'Maruti', 'Maruti', 'Maruti', 'Tata', 'Hyundai', 'Honda', 'Maruti', 'Hyundai', 'Hyundai', 'Hyundai', 'Maruti', 'Maruti', 'Tata', 'Volkswagen', 'Hyundai', 'Tata', 'Mahindra', 'Hyundai', 'Honda', 'Maruti', 'Maruti', 'Volkswagen', 'Maruti', 'Volkswagen', 'Maruti', 'Honda', 'Maruti', 'Hyundai', 'Honda', 'Maruti', 'Honda', 'Hyundai', 'Tata', 'Hyundai', 'Nissan', 'Skoda', 'Maruti', 'Maruti', 'Tata', 'KIA', 'Hyundai', 'KIA', 'Hyundai', 'Hyundai', 'Honda', 'Skoda', 'Toyota', 'Jeep', 'Hyundai', 'Tata', 'Tata', 'Maruti', 'Jeep', 'Renault', 'Tata', 'Maruti', 'Volkswagen', 'Hyundai', 'Hyundai', 'Ford', 'Renault', 'Datsun', 'Maruti', 'Maruti', 'Honda', 'Tata', 'Maruti', 'Volkswagen', 'Hyundai', 'Hyundai', 'Hyundai', 'Hyundai', 'Maruti', 'Nissan', 'Hyundai', 'Hyundai', 'Tata', 'Honda', 'Maruti', 'Hyundai', 'Hyundai', 'MG', 'Hyun
# ...

# %%
sub_brand = []
for i in range(0,len(car_name)):
    a = car_name[i]
    b = a.split()
    sub_brand.append(b[2])
print(sub_brand)
# Out:
# ['Alto', 'Verna', 'Elite', 'Celerio', 'Creta', 'Swift', 'MAGNITE', 'Vitara', 'Jazz', 'Swift', 'XUV300', 'VENUE', 'Alto', 'Ecosport', 'Ecosport', 'Glanza', 'Celerio', 'Baleno', 'Celerio', 'Baleno', 'ALTROZ', 'i20', 'City', 'Swift', 'Creta', 'NEW', 'GRAND', 'Swift', 'Swift', 'NEXON', 'VIRTUS', 'Grand', 'NEXON', 'XUV300', 'i20', 'City', 'Baleno', 'Baleno', 'Ameo', 'Alto', 'Ameo', 'Alto', 'City', 'S', 'Elite', 'City', 'Swift', 'City', 'Eon', 'PUNCH', 'Grand', 'MAGNITE', 'Rapid', 'Baleno', 'Alto', 'Tiago', 'SELTOS', 'Elite', 'SELTOS', 'Creta', 'Verna', 'City', 'Rapid', 'Fortuner', 'Compass', 'Grand', 'Tiago', 'Harrier', 'Swift', 'Compass', 'Duster', 'Safari', 'S', 'Polo', 'NEW', 'Creta', 'Ecosport', 'Kwid', 'Go', 'Dzire', 'BREZZA', 'City', 'NEXON', 'Vitara', 'Vento', 'Creta', 'i10', 'Elite', 'Verna', 'Dzire', 'MAGNITE', 'Creta', 'Grand', 'NEXON', 'Amaze', 'Eeco', 'VENUE', 'Verna', 'HECTOR', 'Tucson', 'Compass', 'Tiago', 'SELTOS', 'Kwid', 'Amaze', 'NEXON', 'Swift', 'Ciaz', 'City', 'Ritz', 
# ...

# %%
distance_covered
# Out:
# ['97,698 KM',
#  '55,921 KM',
#  '66,663 KM',
#  '63,194 KM',
#  '40,368 KM',
#  '1,02,460 KM',
#  '20,338 KM',
#  '29,125 KM',
#  '12,425 KM',
#  '21,574 KM',
#  '64,038 KM',
#  '43,417 KM',
#  '13,185 KM',
#  '68,051 KM',
#  '29,475 KM',
#  '14,642 KM',
#  '61,337 KM',
#  '21,221 KM',
#  '48,066 KM',
#  '35,190 KM',
#  '49,461 KM',
#  '78,624 KM',
#  '1,02,835 KM',
#  '87,820 KM',
#  '29,759 KM',
#  '3,295 KM',
#  '20,631 KM',
#  '47,657 KM',
#  '23,582 KM',
#  '26,202 KM',
#  '27,653 KM',
#  '28,880 KM',
#  '82,375 KM',
#  '20,393 KM',
#  '54,035 KM',
#  '89,726 KM',
#  '38,482 KM',
#  '56,572 KM',
#  '40,904 KM',
#  '39,074 KM',
#  '67,835 KM',
#  '45,475 KM',
#  '34,459 KM',
#  '27,032 KM',
#  '48,575 KM',
#  '28,369 KM',
#  '11,486 KM',
#  '55,879 KM',
#  '86,973 KM',
#  '21,955 KM',
#  '41,163 KM',
#  '36,341 KM',
#  '43,461 KM',
#  '15,650 KM',
#  '9,400 KM',
#  '6,827 KM',
#  '36,166 KM',
#  '27,659 KM',
#  '27,143 KM',
#  '19,352 KM',
#  '40,798 KM',
#  '33,671 KM',
# ...

# %%
distance_covered_ = []
for i in range(0,len(distance_covered)):
    aa =(distance_covered[i].split())
    bb =  aa[0]
    distance_covered_.append(bb)
distance_covered_
# Out:
# ['97,698',
#  '55,921',
#  '66,663',
#  '63,194',
#  '40,368',
#  '1,02,460',
#  '20,338',
#  '29,125',
#  '12,425',
#  '21,574',
#  '64,038',
#  '43,417',
#  '13,185',
#  '68,051',
#  '29,475',
#  '14,642',
#  '61,337',
#  '21,221',
#  '48,066',
#  '35,190',
#  '49,461',
#  '78,624',
#  '1,02,835',
#  '87,820',
#  '29,759',
#  '3,295',
#  '20,631',
#  '47,657',
#  '23,582',
#  '26,202',
#  '27,653',
#  '28,880',
#  '82,375',
#  '20,393',
#  '54,035',
#  '89,726',
#  '38,482',
#  '56,572',
#  '40,904',
#  '39,074',
#  '67,835',
#  '45,475',
#  '34,459',
#  '27,032',
#  '48,575',
#  '28,369',
#  '11,486',
#  '55,879',
#  '86,973',
#  '21,955',
#  '41,163',
#  '36,341',
#  '43,461',
#  '15,650',
#  '9,400',
#  '6,827',
#  '36,166',
#  '27,659',
#  '27,143',
#  '19,352',
#  '40,798',
#  '33,671',
#  '70,102',
#  '1,03,102',
#  '93,467',
#  '32,410',
#  '16,775',
#  '56,690',
#  '53,062',
#  '45,323',
#  '50,108',
#  '30,203',
#  '15,983',
#  '61,297',
#  '21,850',
#  '91,001',
# ...

# %%
amount_lakhs = []
for i in range(0,len(amount)):
    t = amount[i]

    amount_lakhs.append(int((t)*100000))
print(amount_lakhs)
print(len(amount_lakhs))
# Out:
# [241000, 795000, 446000, 405999, 1689000, 340000, 571000, 873000, 572000, 663000, 898000, 871000, 384000, 732000, 610000, 644000, 434999, 649000, 374000, 557000, 629000, 183000, 633000, 459000, 919000, 999000, 551000, 436000, 442000, 1090000, 918000, 398000, 602000, 966000, 503000, 545000, 626000, 658000, 476000, 269000, 376000, 231999, 1042000, 518000, 541000, 1103000, 635000, 881000, 213000, 670000, 386000, 570000, 868000, 780000, 469000, 451999, 1057000, 487000, 986000, 1151000, 877999, 852999, 742000, 2215000, 978999, 430999, 610000, 1095000, 433000, 994000, 930000, 1595000, 852000, 184000, 542000, 646000, 787000, 303000, 338000, 516000, 1205000, 1251000, 836000, 638000, 997000, 753000, 231000, 530000, 759000, 480000, 575000, 1382000, 372000, 823000, 367000, 613000, 836999, 1149000, 1234000, 1250000, 1629000, 501000, 1478000, 370000, 516000, 785000, 614000, 511000, 554000, 277000, 1118000, 766000, 1286000, 1000000, 413000, 699000, 225999, 877000, 744000, 327000, 919000, 766000, 4
# ...

# %%
emi = []
for i in range(0,len(emi)):
    ar = emi[i].split()
    arr = ar[2]
    arr = arr[1::]
    print(arr)

# %%
emi_per_month = emi_amount

# %%
emi_per_month
# Out:
# ['4,712',
#  '15,542',
#  '8,719',
#  '7,937',
#  '32,149',
#  '7,560',
#  '11,163',
#  '16,617',
#  '11,183',
#  '12,962',
#  '17,093',
#  '16,579',
#  '7,507',
#  '16,283',
#  '11,926',
#  '12,590',
#  '8,504',
#  '12,692',
#  '7,312',
#  '10,889',
#  '12,297',
#  '8,614',
#  '14,081',
#  '8,974',
#  '17,492',
#  '19,015',
#  '10,772',
#  '8,524',
#  '8,641',
#  '20,747',
#  '17,473',
#  '7,781',
#  '11,769',
#  '18,383',
#  '9,834',
#  '10,655',
#  '12,238',
#  '12,864',
#  '9,306',
#  '5,259',
#  '7,351',
#  '4,536',
#  '19,834',
#  '10,127',
#  '10,577',
#  '20,995',
#  '12,414',
#  '16,769',
#  '4,164',
#  '13,093',
#  '7,546',
#  '11,144',
#  '16,522',
#  '15,249',
#  '9,169',
#  '8,837',
#  '20,119',
#  '9,521',
#  '18,768',
#  '21,908',
#  '16,708',
#  '16,228',
#  '14,506',
#  '72,516',
#  '21,286',
#  '8,426',
#  '11,926',
#  '23,808',
#  '8,465',
#  '21,612',
#  '17,702',
#  '30,359',
#  '16,217',
#  '6,111',
#  '10,596',
#  '12,629',
#  '15,386',
#  '5,924',
#  '6,598',
# ...

# %%
import pandas as pd 
emi = pd.DataFrame({"EMI_per_month":emi_per_month})
# emi.str.replace(",","")
emi
# Out:
#     EMI_per_month
# 0           4,712
# 1          15,542
# 2           8,719
# 3           7,937
# 4          32,149
# ..            ...
# 845        11,496
# 846        11,085
# 847         6,608
# 848        16,902
# 849         9,658
#
# [850 rows x 1 columns]

# %%
emi_per_month_ = []
for i in emi_per_month:
    rr = i.replace(",","")
    rr = int(rr)
    emi_per_month_.append(rr)
emi_per_month_ = pd.DataFrame({"EMI_PER_MONTH":emi_per_month_})

# %%
emi_per_month_
# Out:
#      EMI_PER_MONTH
# 0             4712
# 1            15542
# 2             8719
# 3             7937
# 4            32149
# ..             ...
# 845          11496
# 846          11085
# 847           6608
# 848          16902
# 849           9658
#
# [850 rows x 1 columns]

# %%
distance_covered_
distance_covered = []
for i in distance_covered_:
    rr = i.replace(",","")
    rr = int(rr)
    distance_covered.append(rr)
distance_covered2 = pd.DataFrame({"Dis_Covered":distance_covered})
distance_covered
len(distance_covered)
# Out:
# 850

# %%
car = pd.DataFrame({"CAR_NAMES":car_name})

# %%
operate_ = pd.DataFrame({"Operate":operate})
operate_
# Out:
#        Operate
# 0       MANUAL
# 1       MANUAL
# 2       MANUAL
# 3       MANUAL
# 4    AUTOMATIC
# ..         ...
# 845     MANUAL
# 846     MANUAL
# 847     MANUAL
# 848     MANUAL
# 849     MANUAL
#
# [850 rows x 1 columns]

# %%
fuel_type
fuel_type2 = pd.DataFrame({"Fuel_Type":fuel_type})

# %%
fuel_type
# Out:
# ['PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'CNG',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'CNG',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
# ...

# %%
amount_ = pd.DataFrame({"AMOUTN":amount_lakhs})

# %%
year_ = pd.DataFrame({"Year":year})

# %%
brand_ = pd.DataFrame({"Brand":brand})

# %%
sub_brand_ = pd.DataFrame({"Sub_Brand":sub_brand})

# %%
for lst in [car_name, year, brand, operate, fuel_type, sub_brand, distance_covered, emi_per_month]:
    print(f"Type: {type(lst)}; Length: {len(lst)}; Sample data: {lst[:5]}")
# Out:
# Type: <class 'list'>; Length: 850; Sample data: ['2016 Maruti Alto 800 LXI', '2019 Hyundai Verna 1.6 VTVT SX', '2015 Hyundai Elite i20 MAGNA 1.2', '2019 Maruti Celerio VXI', '2022 Hyundai Creta SX (O) 1.4 TURBO DCT']
# Type: <class 'list'>; Length: 850; Sample data: [2016, 2019, 2015, 2019, 2022]
# Type: <class 'list'>; Length: 850; Sample data: ['Maruti', 'Hyundai', 'Hyundai', 'Maruti', 'Hyundai']
# Type: <class 'list'>; Length: 850; Sample data: ['MANUAL', 'MANUAL', 'MANUAL', 'MANUAL', 'AUTOMATIC']
# Type: <class 'list'>; Length: 850; Sample data: ['PETROL', 'PETROL', 'PETROL', 'PETROL', 'PETROL']
# Type: <class 'list'>; Length: 850; Sample data: ['Alto', 'Verna', 'Elite', 'Celerio', 'Creta']
# Type: <class 'list'>; Length: 850; Sample data: [97698, 55921, 66663, 63194, 40368]
# Type: <class 'list'>; Length: 850; Sample data: ['4,712', '15,542', '8,719', '7,937', '32,149']

# %%
table3= pd.DataFrame({"CAR_NAME":car_name,"BRAND":brand,"SUB_BRAND":sub_brand,"MODAL_YEAR":year,"AMOUNT":amount_lakhs,"FUEL_TYPE":fuel_type,"DIS_COVERED":distance_covered,"EMI_AMOUNT":emi_per_month,"OPERATE":operate})

# %%
for i in car_name:
    print(i)
# Out:
# 2016 Maruti Alto 800 LXI
# 2019 Hyundai Verna 1.6 VTVT SX
# 2015 Hyundai Elite i20 MAGNA 1.2
# 2019 Maruti Celerio VXI
# 2022 Hyundai Creta SX (O) 1.4 TURBO DCT
# 2015 Maruti Swift VXI
# 2022 Nissan MAGNITE XE
# 2021 Maruti Vitara Brezza VXI AT SHVS
# 2018 Honda Jazz 1.2L I-VTEC V
# 2018 Maruti Swift ZXI PLUS
# 2020 Mahindra XUV300 W8 (O) 1.5 DIESEL AMT
# 2020 Hyundai VENUE SX 1.0 TURBO
# 2022 Maruti Alto LXI O
# 2019 Ford Ecosport TITANIUM 1.5L DIESEL
# 2016 Ford Ecosport TITANIUM+ 1.0L ECOBOOST
# 2019 Toyota Glanza V
# 2017 Maruti Celerio VXI CNG
# 2019 Maruti Baleno ZETA PETROL 1.2
# 2018 Maruti Celerio VXI
# 2019 Maruti Baleno DELTA PETROL 1.2
# 2021 Tata ALTROZ XM PLUS PETROL
# 2011 Hyundai i20 MAGNA 1.2
# 2017 Honda City 1.5L I-VTEC SV
# 2017 Maruti Swift VXI
# 2017 Hyundai Creta SX PLUS AT 1.6 PETROL
# 2024 Hyundai NEW I20 Sportz (O) 1.2 IVT
# 2020 Hyundai GRAND I10 NIOS MAGNA CORPORATE EDITION 1.2 KAPPA VTVT
# 2017 Maruti Swift LXI (O)
# 2017 Maruti Swift LXI (O)
# ...

# %%
table3
# Out:
#                                               CAR_NAME    BRAND SUB_BRAND  \
# 0                             2016 Maruti Alto 800 LXI   Maruti      Alto
# 1                       2019 Hyundai Verna 1.6 VTVT SX  Hyundai     Verna
# 2                     2015 Hyundai Elite i20 MAGNA 1.2  Hyundai     Elite
# 3                              2019 Maruti Celerio VXI   Maruti   Celerio
# 4              2022 Hyundai Creta SX (O) 1.4 TURBO DCT  Hyundai     Creta
# ..                                                 ...      ...       ...
# 845                             2021 Nissan MAGNITE XL   Nissan   MAGNITE
# 846  2019 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT  Hyundai     GRAND
# 847                     2015 Honda Amaze 1.2L I-VTEC E    Honda     Amaze
# 848                          2022 Tata NEXON XZ PETROL     Tata     NEXON
# 849            2018 Ford Ecosport AMBIENTE 1.5L PETROL     Ford  Ecosport
#
#      MODAL_YEAR   AMOUNT FUEL_TYPE  DIS_COVERED EMI_AMOUNT
# ...

# %%
table3.to_csv("Car24_data_delhi-ncr.csv")

# %%
print(len(emi_per_month))
# Out:
# 850

# %%
operate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 operate
#
# NameError: name 'operate' is not defined
